# %%
import nibabel
import numpy as np
import mne

# %%
original_data = mne.io.read_raw_kit('./sub-12/ses-0/meg/sub-12_ses-0_task-0_meg.con')
original_info = original_data.info
# Out:
# Extracting SQD Parameters from ./sub-12/ses-0/meg/sub-12_ses-0_task-0_meg.con...
# Creating Raw.info structure...
# Setting channel info structure...
# Creating Info structure...
# Ready.

# %%
original_info
# Out:
# <Info | 9 non-empty values
#  bads: []
#  ch_names: MEG 001, MEG 002, MEG 003, MEG 004, MEG 005, MEG 006, MEG 007, ...
#  chs: 208 Magnetometers, 16 Reference Magnetometers, 32 misc, 1 Stimulus
#  custom_ref_applied: False
#  description: New York University Abu Dhabi/224-channel MEG System (442) ...
#  highpass: 0.0 Hz
#  kit_system_id: 442 (New York University Abu Dhabi, 2014-)
#  lowpass: 200.0 Hz
#  meas_date: 2017-03-30 11:36:20 UTC
#  nchan: 257
#  projs: []
#  sfreq: 1000.0 Hz
# >

# %%
original_data.get_data().shape
# Out:
# (257, 372000)

# %%
import pandas
import mne_bids

# %%
bids_path = mne_bids.BIDSPath(
subject = '12', session = '0', task='0', datatype= "meg",
root = '.')

# %%
raw = mne_bids.read_raw_bids(bids_path)
# Out:
# Extracting SQD Parameters from sub-12/ses-0/meg/sub-12_ses-0_task-0_meg.con...
# Creating Raw.info structure...
# Setting channel info structure...
# Creating Info structure...
# Ready.
# Reading events from sub-12/ses-0/meg/sub-12_ses-0_task-0_events.tsv.
# Reading channel info from sub-12/ses-0/meg/sub-12_ses-0_task-0_channels.tsv.
# The stimulus channel "STI 014" is present in the raw data, but not included in channels.tsv. Removing the channel.

# %%
raw.load_data().filter(0.5, 30.0, n_jobs=1)
# Out:
# Reading 0 ... 371999  =      0.000 ...   371.999 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 6601 samples (6.601 sec)
# <RawKIT | sub-12_ses-0_task-0_meg.con, 256 x 372000 (372.0 s), ~726.8 MB, data loaded>

# %%
raw.get_data().data.shape
# Out:
# (256, 372000)

# %%
raw
# Out:
# <RawKIT | sub-12_ses-0_task-0_meg.con, 256 x 372000 (372.0 s), ~726.8 MB, data loaded>

# %%
raw.ch_names
# Out:
# ['MEG 001',
#  'MEG 002',
#  'MEG 003',
#  'MEG 004',
#  'MEG 005',
#  'MEG 006',
#  'MEG 007',
#  'MEG 008',
#  'MEG 009',
#  'MEG 010',
#  'MEG 011',
#  'MEG 012',
#  'MEG 013',
#  'MEG 014',
#  'MEG 015',
#  'MEG 016',
#  'MEG 017',
#  'MEG 018',
#  'MEG 019',
#  'MEG 020',
#  'MEG 021',
#  'MEG 022',
#  'MEG 023',
#  'MEG 024',
#  'MEG 025',
#  'MEG 026',
#  'MEG 027',
#  'MEG 028',
#  'MEG 029',
#  'MEG 030',
#  'MEG 031',
#  'MEG 032',
#  'MEG 033',
#  'MEG 034',
#  'MEG 035',
#  'MEG 036',
#  'MEG 037',
#  'MEG 038',
#  'MEG 039',
#  'MEG 040',
#  'MEG 041',
#  'MEG 042',
#  'MEG 043',
#  'MEG 044',
#  'MEG 045',
#  'MEG 046',
#  'MEG 047',
#  'MEG 048',
#  'MEG 049',
#  'MEG 050',
#  'MEG 051',
#  'MEG 052',
#  'MEG 053',
#  'MEG 054',
#  'MEG 055',
#  'MEG 056',
#  'MEG 057',
#  'MEG 058',
#  'MEG 059',
#  'MEG 060',
#  'MEG 061',
#  'MEG 062',
#  'MEG 063',
#  'MEG 064',
#  'MEG 065',
#  'MEG 066',
#  'MEG 067',
#  'MEG 068',
#  'MEG 069',
#  'MEG 070',
#  'MEG 071',
#  'MEG 072',
#  'MEG 073',
#  'MEG 074',
#  'MEG 075',
#  'MEG 076',
#  'MEG 077',
#  'MEG 078',
#  'MEG 079',
#  'MEG 080',
#  'MEG 081',
#  'MEG 082',
#  'MEG 083',
#  'MEG 084',
#  'MEG 085',
#  'MEG 086',
#  'MEG 087',
#  'MEG 088',
#  'MEG 089',
#  'MEG 090',
#  'MEG 091',
#  'MEG 092',
#  'MEG 093',
#  'MEG 094',
#  'MEG 095',
#  'MEG 096',
#  'MEG 097',
#  'MEG 098',
#  'MEG 099',
#  'MEG 100',
#  'MEG 101',
#  'MEG 102',
#  'MEG 103',
#  'MEG 104',
#  'MEG 105',
#  'MEG 106',
#  'MEG 107',
#  'MEG 108',
#  'MEG 109',
#  'MEG 110',
#  'MEG 111',
#  'MEG 112',
#  'MEG 113',
#  'MEG 114',
#  'MEG 115',
#  'MEG 116',
#  'MEG 117',
#  'MEG 118',
#  'MEG 119',
#  'MEG 120',
#  'MEG 121',
#  'MEG 122',
#  'MEG 123',
#  'MEG 124',
#  'MEG 125',
#  'MEG 126',
#  'MEG 127',
#  'MEG 128',
#  'MEG 129',
#  'MEG 130',
#  'MEG 131',
#  'MEG 132',
#  'MEG 133',
#  'MEG 134',
#  'MEG 135',
#  'MEG 136',
#  'MEG 137',
#  'MEG 138',
#  'MEG 139',
#  'MEG 140',
#  'MEG 141',
#  'MEG 142',
#  'MEG 143',
#  'MEG 144',
#  'MEG 145',
#  'MEG 146',
#  'MEG 147',
#  'MEG 148',
#  'MEG 149',
#  'MEG 150',
#  'MEG 151',
#  'MEG 152',
#  'MEG 153',
#  'MEG 154',
#  'MEG 155',
#  'MEG 156',
#  'MEG 157',
#  'MEG 158',
#  'MEG 159',
#  'MEG 160',
#  'MEG 161',
#  'MEG 162',
#  'MEG 163',
#  'MEG 164',
#  'MEG 165',
#  'MEG 166',
#  'MEG 167',
#  'MEG 168',
#  'MEG 169',
#  'MEG 170',
#  'MEG 171',
#  'MEG 172',
#  'MEG 173',
#  'MEG 174',
#  'MEG 175',
#  'MEG 176',
#  'MEG 177',
#  'MEG 178',
#  'MEG 179',
#  'MEG 180',
#  'MEG 181',
#  'MEG 182',
#  'MEG 183',
#  'MEG 184',
#  'MEG 185',
#  'MEG 186',
#  'MEG 187',
#  'MEG 188',
#  'MEG 189',
#  'MEG 190',
#  'MEG 191',
#  'MEG 192',
#  'MEG 193',
#  'MEG 194',
#  'MEG 195',
#  'MEG 196',
#  'MEG 197',
#  'MEG 198',
#  'MEG 199',
#  'MEG 200',
#  'MEG 201',
#  'MEG 202',
#  'MEG 203',
#  'MEG 204',
#  'MEG 205',
#  'MEG 206',
#  'MEG 207',
#  'MEG 208',
#  'MEG 209',
#  'MEG 210',
#  'MEG 211',
#  'MEG 212',
#  'MEG 213',
#  'MEG 214',
#  'MEG 215',
#  'MEG 216',
#  'MEG 217',
#  'MEG 218',
#  'MEG 219',
#  'MEG 220',
#  'MEG 221',
#  'MEG 222',
#  'MEG 223',
#  'MEG 224',
#  'MISC 001',
#  'MISC 002',
#  'MISC 003',
#  'MISC 004',
#  'MISC 005',
#  'MISC 006',
#  'MISC 007',
#  'MISC 008',
#  'MISC 009',
#  'MISC 010',
#  'MISC 011',
#  'MISC 012',
#  'MISC 013',
#  'MISC 014',
#  'MISC 015',
#  'MISC 016',
#  'MISC 017',
#  'MISC 018',
#  'MISC 019',
#  'MISC 020',
#  'MISC 021',
#  'MISC 022',
#  'MISC 023',
#  'MISC 024',
#  'MISC 025',
#  'MISC 026',
#  'MISC 027',
#  'MISC 028',
#  'MISC 029',
#  'MISC 030',
#  'MISC 031',
#  'MISC 032']

# %%
df = raw.annotations.to_data_frame()

# %%
df.shape
# Out:
# (3134, 3)

# %%
df.head(10)
# Out:
#                     onset  duration  \
# 0 2000-01-01 00:00:15.473      0.00
# 1 2000-01-01 00:00:15.473      0.08
# 2 2000-01-01 00:00:15.473      0.30
# 3 2000-01-01 00:00:15.553      0.09
# 4 2000-01-01 00:00:15.643      0.07
# 5 2000-01-01 00:00:15.713      0.06
# 6 2000-01-01 00:00:15.783      0.06
# 7 2000-01-01 00:00:15.783      0.24
# 8 2000-01-01 00:00:15.843      0.04
# 9 2000-01-01 00:00:15.883      0.08
#
#                                          description
# 0  {'index': 23.0, 'subject': 'A0255', 'story': '...
# 1  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 2  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 3  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 4  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 5  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 6  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 7  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 8  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 9  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...

# %%
import pandas as pd
df_new = pd.DataFrame(df.description.apply(eval).to_list())

# %%
df_new.shape
# Out:
# (3134, 17)

# %%
df_new.head(10)
# Out:
#    index subject story  story_uid  sound_id     kind  \
# 0   23.0   A0255   lw1        0.0       0.0    sound
# 1    NaN     NaN   lw1        0.0       0.0  phoneme
# 2    NaN     NaN   lw1        0.0       0.0     word
# 3    NaN     NaN   lw1        0.0       0.0  phoneme
# 4    NaN     NaN   lw1        0.0       0.0  phoneme
# 5    NaN     NaN   lw1        0.0       0.0  phoneme
# 6    NaN     NaN   lw1        0.0       0.0  phoneme
# 7    NaN     NaN   lw1        0.0       0.0     word
# 8    NaN     NaN   lw1        0.0       0.0  phoneme
# 9    NaN     NaN   lw1        0.0       0.0  phoneme
#
#                       meg_file  start                      sound phoneme  \
# 0  A0255_MASC_2_30Mar17_01.con   0.00  stimuli/audio/lw1_0.0.wav     NaN
# 1  A0255_MASC_2_30Mar17_01.con   0.00    stimuli/audio/lw1_0.wav     t_B
# 2  A0255_MASC_2_30Mar17_01.con   0.00    stimuli/audio/lw1_0.wav     NaN
# 3  A0255_MASC_2_30Mar17_01.con   0.08    stimuli/audio/lw1_0.wav    eh_I
# 4  A0255_MASC_2_30Mar17_01.con   0.17    stimuli/audio/lw1_0.wav     r_I
# 5  A0255_MASC_2_30Mar17_01.con   0.24    stimuli/audio/lw1_0.wav    ah_E
# 6  A0255_MASC_2_30Mar17_01.con   0.31    stimuli/audio/lw1_0.wav     s_B
# 7  A0255_MASC_2_30Mar17_01.con   0.31    stimuli/audio/lw1_0.wav     NaN
# 8  A0255_MASC_2_30Mar17_01.con   0.37    stimuli/audio/lw1_0.wav     t_I
# 9  A0255_MASC_2_30Mar17_01.con   0.41    stimuli/audio/lw1_0.wav    uh_I
#
#    sequence_id condition  word_index  speech_rate    voice  pronounced   word
# 0          NaN       NaN         NaN          NaN      NaN         NaN    NaN
# 1          0.0  sentence         0.0        205.0  Allison         1.0    NaN
# 2          0.0  sentence         0.0        205.0  Allison         1.0   Tara
# 3          0.0  sentence         0.0        205.0  Allison         1.0    NaN
# 4          0.0  sentence         0.0        205.0  Allison         1.0    NaN
# 5          0.0  sentence         0.0        205.0  Allison         1.0    NaN
# 6          0.0  sentence         1.0        205.0  Allison         1.0    NaN
# 7          0.0  sentence         1.0        205.0  Allison         1.0  stood
# 8          0.0  sentence         1.0        205.0  Allison         1.0    NaN
# 9          0.0  sentence         1.0        205.0  Allison         1.0    NaN

# %%
df.iloc[0:20]
# Out:
#                      onset  duration  \
# 0  2000-01-01 00:00:15.473      0.00
# 1  2000-01-01 00:00:15.473      0.08
# 2  2000-01-01 00:00:15.473      0.30
# 3  2000-01-01 00:00:15.553      0.09
# 4  2000-01-01 00:00:15.643      0.07
# 5  2000-01-01 00:00:15.713      0.06
# 6  2000-01-01 00:00:15.783      0.06
# 7  2000-01-01 00:00:15.783      0.24
# 8  2000-01-01 00:00:15.843      0.04
# 9  2000-01-01 00:00:15.883      0.08
# 10 2000-01-01 00:00:15.963      0.06
# 11 2000-01-01 00:00:16.023      0.05
# 12 2000-01-01 00:00:16.023      0.37
# 13 2000-01-01 00:00:16.073      0.07
# 14 2000-01-01 00:00:16.143      0.12
# 15 2000-01-01 00:00:16.263      0.13
# 16 2000-01-01 00:00:16.553      0.08
# 17 2000-01-01 00:00:16.553      0.40
# 18 2000-01-01 00:00:16.633      0.07
# 19 2000-01-01 00:00:16.703      0.11
#
#                                           description
# 0   {'index': 23.0, 'subject': 'A0255', 'story': '...
# 1   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 2   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 3   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 4   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 5   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 6   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 7   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 8   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 9   {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 10  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 11  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 12  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 13  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 14  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 15  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 16  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 17  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 18  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 19  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...

# %%
df_new.iloc[0:50]
# Out:
#     index subject story  story_uid  sound_id     kind  \
# 0    23.0   A0255   lw1        0.0       0.0    sound
# 1     NaN     NaN   lw1        0.0       0.0  phoneme
# 2     NaN     NaN   lw1        0.0       0.0     word
# 3     NaN     NaN   lw1        0.0       0.0  phoneme
# 4     NaN     NaN   lw1        0.0       0.0  phoneme
# 5     NaN     NaN   lw1        0.0       0.0  phoneme
# 6     NaN     NaN   lw1        0.0       0.0  phoneme
# 7     NaN     NaN   lw1        0.0       0.0     word
# 8     NaN     NaN   lw1        0.0       0.0  phoneme
# 9     NaN     NaN   lw1        0.0       0.0  phoneme
# 10    NaN     NaN   lw1        0.0       0.0  phoneme
# 11    NaN     NaN   lw1        0.0       0.0  phoneme
# 12    NaN     NaN   lw1        0.0       0.0     word
# 13    NaN     NaN   lw1        0.0       0.0  phoneme
# 14    NaN     NaN   lw1        0.0       0.0  phoneme
# 15    NaN     NaN   lw1        0.0       0.0  phoneme
# 16    NaN     NaN   lw1        0.0       0.0  phoneme
# 17    NaN     NaN   lw1        0.0       0.0     word
# 18    NaN     NaN   lw1        0.0       0.0  phoneme
# 19    NaN     NaN   lw1        0.0       0.0  phoneme
# 20    NaN     NaN   lw1        0.0       0.0  phoneme
# 21    NaN     NaN   lw1        0.0       0.0  phoneme
# 22    NaN     NaN   lw1        0.0       0.0     word
# 23    NaN     NaN   lw1        0.0       0.0  phoneme
# 24    NaN     NaN   lw1        0.0       0.0  phoneme
# 25    NaN     NaN   lw1        0.0       0.0  phoneme
# 26    NaN     NaN   lw1        0.0       0.0  phoneme
# 27    NaN     NaN   lw1        0.0       0.0  phoneme
# 28    NaN     NaN   lw1        0.0       0.0     word
# 29    NaN     NaN   lw1        0.0       0.0  phoneme
# 30    NaN     NaN   lw1        0.0       0.0  phoneme
# 31    NaN     NaN   lw1        0.0       0.0     word
# 32    NaN     NaN   lw1        0.0       0.0  phoneme
# 33    NaN     NaN   lw1        0.0       0.0  phoneme
# 34    NaN     NaN   lw1        0.0       0.0     word
# 35    NaN     NaN   lw1        0.0       0.0  phoneme
# 36    NaN     NaN   lw1        0.0       0.0  phoneme
# 37    NaN     NaN   lw1        0.0       0.0  phoneme
# 38    NaN     NaN   lw1        0.0       0.0  phoneme
# 39    NaN     NaN   lw1        0.0       0.0     word
# 40    NaN     NaN   lw1        0.0       0.0  phoneme
# 41    NaN     NaN   lw1        0.0       0.0  phoneme
# 42    NaN     NaN   lw1        0.0       0.0  phoneme
# 43    NaN     NaN   lw1        0.0       0.0  phoneme
# 44    NaN     NaN   lw1        0.0       0.0     word
# 45    NaN     NaN   lw1        0.0       0.0  phoneme
# 46    NaN     NaN   lw1        0.0       0.0  phoneme
# 47    NaN     NaN   lw1        0.0       0.0  phoneme
# 48    NaN     NaN   lw1        0.0       0.0  phoneme
# 49    NaN     NaN   lw1        0.0       0.0     word
#
#                        meg_file  start                      sound phoneme  \
# 0   A0255_MASC_2_30Mar17_01.con   0.00  stimuli/audio/lw1_0.0.wav     NaN
# 1   A0255_MASC_2_30Mar17_01.con   0.00    stimuli/audio/lw1_0.wav     t_B
# 2   A0255_MASC_2_30Mar17_01.con   0.00    stimuli/audio/lw1_0.wav     NaN
# 3   A0255_MASC_2_30Mar17_01.con   0.08    stimuli/audio/lw1_0.wav    eh_I
# 4   A0255_MASC_2_30Mar17_01.con   0.17    stimuli/audio/lw1_0.wav     r_I
# 5   A0255_MASC_2_30Mar17_01.con   0.24    stimuli/audio/lw1_0.wav    ah_E
# 6   A0255_MASC_2_30Mar17_01.con   0.31    stimuli/audio/lw1_0.wav     s_B
# 7   A0255_MASC_2_30Mar17_01.con   0.31    stimuli/audio/lw1_0.wav     NaN
# 8   A0255_MASC_2_30Mar17_01.con   0.37    stimuli/audio/lw1_0.wav     t_I
# 9   A0255_MASC_2_30Mar17_01.con   0.41    stimuli/audio/lw1_0.wav    uh_I
# 10  A0255_MASC_2_30Mar17_01.con   0.49    stimuli/audio/lw1_0.wav     d_E
# 11  A0255_MASC_2_30Mar17_01.con   0.55    stimuli/audio/lw1_0.wav     s_B
# 12  A0255_MASC_2_30Mar17_01.con   0.55    stimuli/audio/lw1_0.wav     NaN
# 13  A0255_MASC_2_30Mar17_01.con   0.60    stimuli/audio/lw1_0.wav     t_I
# 14  A0255_MASC_2_30Mar17_01.con   0.67    stimuli/audio/lw1_0.wav    aa_I
# 15  A0255_MASC_2_30Mar17_01.con   0.79    stimuli/audio/lw1_0.wav     k_E
# 16  A0255_MASC_2_30Mar17_01.con   1.08    stimuli/audio/lw1_0.wav     s_B
# 17  A0255_MASC_2_30Mar17_01.con   1.08    stimuli/audio/lw1_0.wav     NaN
# 18  A0255_MASC_2_30Mar17_01.con   1.16    stimuli/audio/lw1_0.wav     t_I
# 19  A0255_MASC_2_30Mar17_01.con   1.23    stimuli/audio/lw1_0.wav    ih_I
# 20  A0255_MASC_2_30Mar17_01.con   1.34    stimuli/audio/lw1_0.wav     l_E
# 21  A0255_MASC_2_30Mar17_01.con   1.63    stimuli/audio/lw1_0.wav     w_B
# 22  A0255_MASC_2_30Mar17_01.con   1.63    stimuli/audio/lw1_0.wav     NaN
# 23  A0255_MASC_2_30Mar17_01.con   1.77    stimuli/audio/lw1_0.wav    ey_I
# 24  A0255_MASC_2_30Mar17_01.con   1.84    stimuli/audio/lw1_0.wav     t_I
# 25  A0255_MASC_2_30Mar17_01.con   1.89    stimuli/audio/lw1_0.wav    ih_I
# 26  A0255_MASC_2_30Mar17_01.con   1.96    stimuli/audio/lw1_0.wav    ng_E
# 27  A0255_MASC_2_30Mar17_01.con   2.04    stimuli/audio/lw1_0.wav     f_B
# 28  A0255_MASC_2_30Mar17_01.con   2.04    stimuli/audio/lw1_0.wav     NaN
# 29  A0255_MASC_2_30Mar17_01.con   2.09    stimuli/audio/lw1_0.wav    er_E
# 30  A0255_MASC_2_30Mar17_01.con   2.17    stimuli/audio/lw1_0.wav    dh_B
# 31  A0255_MASC_2_30Mar17_01.con   2.17    stimuli/audio/lw1_0.wav     NaN
# 32  A0255_MASC_2_30Mar17_01.con   2.20    stimuli/audio/lw1_0.wav    ah_E
# 33  A0255_MASC_2_30Mar17_01.con   2.26    stimuli/audio/lw1_0.wav     f_B
# 34  A0255_MASC_2_30Mar17_01.con   2.26    stimuli/audio/lw1_0.wav     NaN
# 35  A0255_MASC_2_30Mar17_01.con   2.33    stimuli/audio/lw1_0.wav    er_I
# 36  A0255_MASC_2_30Mar17_01.con   2.45    stimuli/audio/lw1_0.wav     s_I
# 37  A0255_MASC_2_30Mar17_01.con   2.51    stimuli/audio/lw1_0.wav     t_E
# 38  A0255_MASC_2_30Mar17_01.con   2.54    stimuli/audio/lw1_0.wav     t_B
# 39  A0255_MASC_2_30Mar17_01.con   2.54    stimuli/audio/lw1_0.wav     NaN
# 40  A0255_MASC_2_30Mar17_01.con   2.62    stimuli/audio/lw1_0.wav    ay_I
# 41  A0255_MASC_2_30Mar17_01.con   2.74    stimuli/audio/lw1_0.wav     n_I
# 42  A0255_MASC_2_30Mar17_01.con   2.79    stimuli/audio/lw1_0.wav    iy_E
# 43  A0255_MASC_2_30Mar17_01.con   2.85    stimuli/audio/lw1_0.wav     g_B
# 44  A0255_MASC_2_30Mar17_01.con   2.85    stimuli/audio/lw1_0.wav     NaN
# 45  A0255_MASC_2_30Mar17_01.con   2.90    stimuli/audio/lw1_0.wav     l_I
# 46  A0255_MASC_2_30Mar17_01.con   2.96    stimuli/audio/lw1_0.wav    iy_I
# 47  A0255_MASC_2_30Mar17_01.con   3.03    stimuli/audio/lw1_0.wav     m_E
# 48  A0255_MASC_2_30Mar17_01.con   3.10    stimuli/audio/lw1_0.wav     f_B
# 49  A0255_MASC_2_30Mar17_01.con   3.10    stimuli/audio/lw1_0.wav     NaN
#
#     sequence_id condition  word_index  speech_rate    voice  pronounced  \
# 0           NaN       NaN         NaN          NaN      NaN         NaN
# 1           0.0  sentence         0.0        205.0  Allison         1.0
# 2           0.0  sentence         0.0        205.0  Allison         1.0
# 3           0.0  sentence         0.0        205.0  Allison         1.0
# 4           0.0  sentence         0.0        205.0  Allison         1.0
# 5           0.0  sentence         0.0        205.0  Allison         1.0
# 6           0.0  sentence         1.0        205.0  Allison         1.0
# 7           0.0  sentence         1.0        205.0  Allison         1.0
# 8           0.0  sentence         1.0        205.0  Allison         1.0
# 9           0.0  sentence         1.0        205.0  Allison         1.0
# 10          0.0  sentence         1.0        205.0  Allison         1.0
# 11          0.0  sentence         2.0        205.0  Allison         1.0
# 12          0.0  sentence         2.0        205.0  Allison         1.0
# 13          0.0  sentence         2.0        205.0  Allison         1.0
# 14          0.0  sentence         2.0        205.0  Allison         1.0
# 15          0.0  sentence         2.0        205.0  Allison         1.0
# 16          0.0  sentence         3.0        205.0  Allison         1.0
# 17          0.0  sentence         3.0        205.0  Allison         1.0
# 18          0.0  sentence         3.0        205.0  Allison         1.0
# 19          0.0  sentence         3.0        205.0  Allison         1.0
# 20          0.0  sentence         3.0        205.0  Allison         1.0
# 21          0.0  sentence         4.0        205.0  Allison         1.0
# 22          0.0  sentence         4.0        205.0  Allison         1.0
# 23          0.0  sentence         4.0        205.0  Allison         1.0
# 24          0.0  sentence         4.0        205.0  Allison         1.0
# 25          0.0  sentence         4.0        205.0  Allison         1.0
# 26          0.0  sentence         4.0        205.0  Allison         1.0
# 27          0.0  sentence         5.0        205.0  Allison         1.0
# 28          0.0  sentence         5.0        205.0  Allison         1.0
# 29          0.0  sentence         5.0        205.0  Allison         1.0
# 30          0.0  sentence         6.0        205.0  Allison         1.0
# 31          0.0  sentence         6.0        205.0  Allison         1.0
# 32          0.0  sentence         6.0        205.0  Allison         1.0
# 33          0.0  sentence         7.0        205.0  Allison         1.0
# 34          0.0  sentence         7.0        205.0  Allison         1.0
# 35          0.0  sentence         7.0        205.0  Allison         1.0
# 36          0.0  sentence         7.0        205.0  Allison         1.0
# 37          0.0  sentence         7.0        205.0  Allison         1.0
# 38          0.0  sentence         8.0        205.0  Allison         1.0
# 39          0.0  sentence         8.0        205.0  Allison         1.0
# 40          0.0  sentence         8.0        205.0  Allison         1.0
# 41          0.0  sentence         8.0        205.0  Allison         1.0
# 42          0.0  sentence         8.0        205.0  Allison         1.0
# 43          0.0  sentence         9.0        205.0  Allison         1.0
# 44          0.0  sentence         9.0        205.0  Allison         1.0
# 45          0.0  sentence         9.0        205.0  Allison         1.0
# 46          0.0  sentence         9.0        205.0  Allison         1.0
# 47          0.0  sentence         9.0        205.0  Allison         1.0
# 48          0.0  sentence        10.0        205.0  Allison         1.0
# 49          0.0  sentence        10.0        205.0  Allison         1.0
#
#        word
# 0       NaN
# 1       NaN
# 2      Tara
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7     stood
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12    stock
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17    still
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22  waiting
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      for
# 29      NaN
# 30      NaN
# 31      the
# 32      NaN
# 33      NaN
# 34    first
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39     tiny
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44    gleam
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49     from

# %%
df_new[df_new['kind']=='sound'].head()
# Out:
#       index subject story  story_uid  sound_id   kind  \
# 0      23.0   A0255   lw1        0.0       0.0  sound
# 873    25.0   A0255   lw1        0.0       1.0  sound
# 1527   27.0   A0255   lw1        0.0       2.0  sound
# 2551   29.0   A0255   lw1        0.0       3.0  sound
#
#                          meg_file  start                      sound phoneme  \
# 0     A0255_MASC_2_30Mar17_01.con    0.0  stimuli/audio/lw1_0.0.wav     NaN
# 873   A0255_MASC_2_30Mar17_01.con    0.0  stimuli/audio/lw1_1.0.wav     NaN
# 1527  A0255_MASC_2_30Mar17_01.con    0.0  stimuli/audio/lw1_2.0.wav     NaN
# 2551  A0255_MASC_2_30Mar17_01.con    0.0  stimuli/audio/lw1_3.0.wav     NaN
#
#       sequence_id condition  word_index  speech_rate voice  pronounced word
# 0             NaN       NaN         NaN          NaN   NaN         NaN  NaN
# 873           NaN       NaN         NaN          NaN   NaN         NaN  NaN
# 1527          NaN       NaN         NaN          NaN   NaN         NaN  NaN
# 2551          NaN       NaN         NaN          NaN   NaN         NaN  NaN

# %%
df_new['kind'].value_counts()
# Out:
# phoneme    2462
# word        668
# sound         4
# Name: kind, dtype: int64

# %%
df_new[df_new['kind']=='phoneme'].groupby('phoneme').head()
# Out:
#       index subject story  story_uid  sound_id     kind  \
# 1       NaN     NaN   lw1        0.0       0.0  phoneme
# 3       NaN     NaN   lw1        0.0       0.0  phoneme
# 4       NaN     NaN   lw1        0.0       0.0  phoneme
# 5       NaN     NaN   lw1        0.0       0.0  phoneme
# 6       NaN     NaN   lw1        0.0       0.0  phoneme
# ...     ...     ...   ...        ...       ...      ...
# 2914    NaN     NaN   lw1        0.0       3.0  phoneme
# 2936    NaN     NaN   lw1        0.0       3.0  phoneme
# 2986    NaN     NaN   lw1        0.0       3.0  phoneme
# 3047    NaN     NaN   lw1        0.0       3.0  phoneme
# 3079    NaN     NaN   lw1        0.0       3.0  phoneme
#
#                          meg_file  start                    sound phoneme  \
# 1     A0255_MASC_2_30Mar17_01.con   0.00  stimuli/audio/lw1_0.wav     t_B
# 3     A0255_MASC_2_30Mar17_01.con   0.08  stimuli/audio/lw1_0.wav    eh_I
# 4     A0255_MASC_2_30Mar17_01.con   0.17  stimuli/audio/lw1_0.wav     r_I
# 5     A0255_MASC_2_30Mar17_01.con   0.24  stimuli/audio/lw1_0.wav    ah_E
# 6     A0255_MASC_2_30Mar17_01.con   0.31  stimuli/audio/lw1_0.wav     s_B
# ...                           ...    ...                      ...     ...
# 2914  A0255_MASC_2_30Mar17_01.con  33.98  stimuli/audio/lw1_3.wav    ch_B
# 2936  A0255_MASC_2_30Mar17_01.con  35.29  stimuli/audio/lw1_3.wav     p_E
# 2986  A0255_MASC_2_30Mar17_01.con  39.98  stimuli/audio/lw1_3.wav    th_I
# 3047  A0255_MASC_2_30Mar17_01.con  46.34  stimuli/audio/lw1_3.wav     g_E
# 3079  A0255_MASC_2_30Mar17_01.con  48.51  stimuli/audio/lw1_3.wav     g_E
#
#       sequence_id  condition  word_index  speech_rate    voice  pronounced  \
# 1             0.0   sentence         0.0        205.0  Allison         1.0
# 3             0.0   sentence         0.0        205.0  Allison         1.0
# 4             0.0   sentence         0.0        205.0  Allison         1.0
# 5             0.0   sentence         0.0        205.0  Allison         1.0
# 6             0.0   sentence         1.0        205.0  Allison         1.0
# ...           ...        ...         ...          ...      ...         ...
# 2914         49.0   sentence        24.0        205.0  Allison         1.0
# 2936         49.0   sentence        27.0        205.0  Allison         1.0
# 2986         50.0   sentence        13.0        205.0  Allison         1.0
# 3047         51.0  word_list        11.0        205.0  Allison         1.0
# 3079         52.0   sentence         6.0        205.0  Allison         1.0
#
#      word
# 1     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# ...   ...
# 2914  NaN
# 2936  NaN
# 2986  NaN
# 3047  NaN
# 3079  NaN
#
# [455 rows x 17 columns]

# %%
df_new.iloc[874]
# Out:
# index                                  NaN
# subject                                NaN
# story                                  lw1
# story_uid                                0
# sound_id                                 1
# kind                               phoneme
# meg_file       A0255_MASC_2_30Mar17_01.con
# start                                 0.44
# sound              stimuli/audio/lw1_1.wav
# phoneme                                w_B
# sequence_id                             14
# condition                         sentence
# word_index                               2
# speech_rate                            145
# voice                              Allison
# pronounced                               1
# word                                   NaN
# Name: 874, dtype: object

# %%
df_new['kind'].value_counts()
# Out:
# phoneme    2462
# word        668
# sound         4
# Name: kind, dtype: int64

# %%
df.iloc[850:900]
# Out:
#                       onset  duration  \
# 850 2000-01-01 00:01:48.833      0.06
# 851 2000-01-01 00:01:48.893      0.05
# 852 2000-01-01 00:01:48.943      0.07
# 853 2000-01-01 00:01:49.013      0.07
# 854 2000-01-01 00:01:49.093      0.08
# 855 2000-01-01 00:01:49.093      0.15
# 856 2000-01-01 00:01:49.173      0.07
# 857 2000-01-01 00:01:49.243      0.07
# 858 2000-01-01 00:01:49.243      0.52
# 859 2000-01-01 00:01:49.313      0.08
# 860 2000-01-01 00:01:49.393      0.09
# 861 2000-01-01 00:01:49.483      0.16
# 862 2000-01-01 00:01:49.643      0.09
# 863 2000-01-01 00:01:49.733      0.03
# 864 2000-01-01 00:01:49.763      0.04
# 865 2000-01-01 00:01:49.763      0.96
# 866 2000-01-01 00:01:49.803      0.11
# 867 2000-01-01 00:01:49.913      0.09
# 868 2000-01-01 00:01:50.003      0.10
# 869 2000-01-01 00:01:50.103      0.08
# 870 2000-01-01 00:01:50.183      0.10
# 871 2000-01-01 00:01:50.283      0.19
# 872 2000-01-01 00:01:50.473      0.25
# 873 2000-01-01 00:02:02.818      0.00
# 874 2000-01-01 00:02:03.258      0.09
# 875 2000-01-01 00:02:03.258      0.21
# 876 2000-01-01 00:02:03.348      0.06
# 877 2000-01-01 00:02:03.408      0.06
# 878 2000-01-01 00:02:03.468      0.09
# 879 2000-01-01 00:02:03.468      0.09
# 880 2000-01-01 00:02:03.568      0.11
# 881 2000-01-01 00:02:03.568      0.27
# 882 2000-01-01 00:02:03.678      0.09
# 883 2000-01-01 00:02:03.768      0.07
# 884 2000-01-01 00:02:03.838      0.07
# 885 2000-01-01 00:02:03.838      0.15
# 886 2000-01-01 00:02:03.908      0.03
# 887 2000-01-01 00:02:03.938      0.05
# 888 2000-01-01 00:02:03.988      0.06
# 889 2000-01-01 00:02:03.988      0.28
# 890 2000-01-01 00:02:04.048      0.16
# 891 2000-01-01 00:02:04.208      0.06
# 892 2000-01-01 00:02:04.278      0.11
# 893 2000-01-01 00:02:04.278      0.46
# 894 2000-01-01 00:02:04.388      0.08
# 895 2000-01-01 00:02:04.468      0.06
# 896 2000-01-01 00:02:04.528      0.10
# 897 2000-01-01 00:02:04.628      0.11
# 898 2000-01-01 00:02:04.738      0.08
# 899 2000-01-01 00:02:04.738      1.07
#
#                                            description
# 850  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 851  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 852  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 853  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 854  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 855  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 856  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 857  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 858  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 859  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 860  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 861  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 862  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 863  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 864  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 865  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 866  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 867  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 868  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 869  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 870  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 871  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 872  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 873  {'index': 25.0, 'subject': 'A0255', 'story': '...
# 874  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 875  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 876  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 877  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 878  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 879  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 880  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 881  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 882  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 883  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 884  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 885  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 886  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 887  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 888  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 889  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 890  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 891  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 892  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 893  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 894  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 895  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 896  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 897  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 898  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...
# 899  {'story': 'lw1', 'story_uid': 0.0, 'sound_id':...

# %%
ph_info = pd.read_csv("phoneme_info.csv")
subjects = pd.read_csv("participants.tsv", sep="\t")
subjects = subjects.participant_id.apply(lambda x: x.split("-")[1]).values

# %%
# preproc annotations
from wordfreq import zipf_frequency
meta = list()
for annot in raw.annotations:
    d = eval(annot.pop("description"))
    for k, v in annot.items():
        assert k not in d.keys()
        d[k] = v
    meta.append(d)
meta = pd.DataFrame(meta)
meta["intercept"] = 1.0

# compute voicing
phonemes = meta.query('kind=="phoneme"')
assert len(phonemes)
for ph, d in phonemes.groupby("phoneme"):
    ph = ph.split("_")[0]
    match = ph_info.query("phoneme==@ph")
    assert len(match) == 1
    meta.loc[d.index, "voiced"] = match.iloc[0].phonation == "v"

# compute word frquency and merge w/ phoneme
meta["is_word"] = False
words = meta.query('kind=="word"').copy()
assert len(words) > 10
# assert np.all(meta.loc[words.index + 1, "kind"] == "phoneme")
meta.loc[words.index + 1, "is_word"] = True
wfreq = lambda x: zipf_frequency(x, "en")  # noqa
meta.loc[words.index + 1, "wordfreq"] = words.word.apply(wfreq).values

meta = meta.query('kind=="phoneme"')
assert len(meta.wordfreq.unique()) > 2

# segment
events = np.c_[
    meta.onset * raw.info["sfreq"], np.ones((len(meta), 2))
].astype(int)

epochs = mne.Epochs(
    raw,
    events,
    tmin=-0.2,
    tmax=0.6,
    decim=10,
    baseline=(0.0, 0.0),
    metadata=meta,
    preload=True,
    event_repeated="drop",
)

# threshold
th = np.percentile(np.abs(epochs._data), 95)
epochs._data[:] = np.clip(epochs._data, -th, th)
epochs.apply_baseline()
th = np.percentile(np.abs(epochs._data), 95)
epochs._data[:] = np.clip(epochs._data, -th, th)
epochs.apply_baseline()
# Out:
# Adding metadata with 24 columns
# 2462 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 2462 events and 801 original time points (prior to decimation) ...
# 0 bad epochs dropped
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# <Epochs |  2462 events (all good), -0.2 - 0.6 sec, baseline -0.2 – 0 sec, ~389.7 MB, data loaded, with metadata,
#  '1': 2462>

# %%
epochs.metadata["half"] = np.round(
                np.linspace(0, 1.0, len(epochs))
            ).astype(int)
epochs.metadata["task"] = '0'
epochs.metadata["session"] = '0'

# %%
words = epochs["is_word"]
X = words.get_data() * 1e13

# %%
X.shape
# Out:
# (668, 256, 81)

# %%
epochs.annotations.description
# Out:
# array(["{'index': 23.0, 'subject': 'A0255', 'story': 'lw1', 'story_uid': 0.0, 'sound_id': 0.0, 'kind': 'sound', 'meg_file': 'A0255_MASC_2_30Mar17_01.con', 'start': 0.0, 'sound': 'stimuli/audio/lw1_0.0.wav'}",
#        "{'story': 'lw1', 'story_uid': 0.0, 'sound_id': 0.0, 'kind': 'phoneme', 'meg_file': 'A0255_MASC_2_30Mar17_01.con', 'start': 0.0, 'sound': 'stimuli/audio/lw1_0.wav', 'phoneme': 't_B', 'sequence_id': 0.0, 'condition': 'sentence', 'word_index': 0.0, 'speech_rate': 205.0, 'voice': 'Allison', 'pronounced': 1.0}",
#        "{'story': 'lw1', 'story_uid': 0.0, 'sound_id': 0.0, 'kind': 'word', 'meg_file': 'A0255_MASC_2_30Mar17_01.con', 'start': 0.0, 'sound': 'stimuli/audio/lw1_0.wav', 'word': 'Tara', 'sequence_id': 0.0, 'condition': 'sentence', 'word_index': 0.0, 'speech_rate': 205.0, 'voice': 'Allison', 'pronounced': 1.0}",
#        ...,
#        "{'story': 'lw1', 'story_uid': 0.0, 'sound_id': 3.0, 'kind': 'phoneme', 'meg_file': 'A0255_MASC_2_30Mar17_01.con', 'start': 52.03, 'sound': 'stimuli/audio/lw1_3.wav', 'phoneme': 'sh_I', 'sequence_id': 52.0, 'condition': 'sentence', 'word_index': 22.0, 'speech_rate': 205.0, 'voice': 'Allison', 'pronounced': 1.0}",
#        "{'story': 'lw1', 'story_uid': 0.0, 'sound_id': 3.0, 'kind': 'phoneme', 'meg_file': 'A0255_MASC_2_30Mar17_01.con', 'start': 52.11, 'sound': 'stimuli/audio/lw1_3.wav', 'phoneme': 'iy_I', 'sequence_id': 52.0, 'condition': 'sentence', 'word_index': 22.0, 'speech_rate': 205.0, 'voice': 'Allison', 'pronounced': 1.0}",
#        "{'story': 'lw1', 'story_uid': 0.0, 'sound_id': 3.0, 'kind': 'phoneme', 'meg_file': 'A0255_MASC_2_30Mar17_01.con', 'start': 52.12, 'sound': 'stimuli/audio/lw1_3.wav', 'phoneme': 'z_E', 'sequence_id': 52.0, 'condition': 'sentence', 'word_index': 22.0, 'speech_rate': 205.0, 'voice': 'Allison', 'pronounced': 1.0}"],
#       dtype='<U318')

# %%
meta.head()
# Out:
#    index subject story  story_uid  sound_id     kind  \
# 1    NaN     NaN   lw1        0.0       0.0  phoneme
# 3    NaN     NaN   lw1        0.0       0.0  phoneme
# 4    NaN     NaN   lw1        0.0       0.0  phoneme
# 5    NaN     NaN   lw1        0.0       0.0  phoneme
# 6    NaN     NaN   lw1        0.0       0.0  phoneme
#
#                       meg_file  start                    sound   onset  ...  \
# 1  A0255_MASC_2_30Mar17_01.con   0.00  stimuli/audio/lw1_0.wav  15.473  ...
# 3  A0255_MASC_2_30Mar17_01.con   0.08  stimuli/audio/lw1_0.wav  15.553  ...
# 4  A0255_MASC_2_30Mar17_01.con   0.17  stimuli/audio/lw1_0.wav  15.643  ...
# 5  A0255_MASC_2_30Mar17_01.con   0.24  stimuli/audio/lw1_0.wav  15.713  ...
# 6  A0255_MASC_2_30Mar17_01.con   0.31  stimuli/audio/lw1_0.wav  15.783  ...
#
#    condition word_index speech_rate    voice pronounced  word  intercept  \
# 1   sentence        0.0       205.0  Allison        1.0   NaN        1.0
# 3   sentence        0.0       205.0  Allison        1.0   NaN        1.0
# 4   sentence        0.0       205.0  Allison        1.0   NaN        1.0
# 5   sentence        0.0       205.0  Allison        1.0   NaN        1.0
# 6   sentence        1.0       205.0  Allison        1.0   NaN        1.0
#
#   voiced  is_word wordfreq
# 1  False    False      NaN
# 3   True     True     3.66
# 4   True    False      NaN
# 5   True    False      NaN
# 6  False    False      NaN
#
# [5 rows x 24 columns]

# %%
y = words.metadata["wordfreq"].values

# %%
y.shape
# Out:
# (668,)

# %%
def plot(result):
    fig, ax = plt.subplots(1, figsize=[6, 6])
    sns.lineplot(x="time", y="score", data=result, hue="label", ax=ax)
    ax.axhline(0, color="k")
    return fig

# %%
# Phonemes
phonemes = epochs["not is_word"]
evo = phonemes.average()
fig_evo_ph = evo.plot(spatial_colors=True, show=False)

# %%
phonemes.metadata.iloc[0:50]
# Out:
#     index subject story  story_uid  sound_id     kind  \
# 0     NaN     NaN   lw1        0.0       0.0  phoneme
# 2     NaN     NaN   lw1        0.0       0.0  phoneme
# 3     NaN     NaN   lw1        0.0       0.0  phoneme
# 4     NaN     NaN   lw1        0.0       0.0  phoneme
# 6     NaN     NaN   lw1        0.0       0.0  phoneme
# 7     NaN     NaN   lw1        0.0       0.0  phoneme
# 8     NaN     NaN   lw1        0.0       0.0  phoneme
# 10    NaN     NaN   lw1        0.0       0.0  phoneme
# 11    NaN     NaN   lw1        0.0       0.0  phoneme
# 12    NaN     NaN   lw1        0.0       0.0  phoneme
# 14    NaN     NaN   lw1        0.0       0.0  phoneme
# 15    NaN     NaN   lw1        0.0       0.0  phoneme
# 16    NaN     NaN   lw1        0.0       0.0  phoneme
# 18    NaN     NaN   lw1        0.0       0.0  phoneme
# 19    NaN     NaN   lw1        0.0       0.0  phoneme
# 20    NaN     NaN   lw1        0.0       0.0  phoneme
# 21    NaN     NaN   lw1        0.0       0.0  phoneme
# 23    NaN     NaN   lw1        0.0       0.0  phoneme
# 25    NaN     NaN   lw1        0.0       0.0  phoneme
# 27    NaN     NaN   lw1        0.0       0.0  phoneme
# 28    NaN     NaN   lw1        0.0       0.0  phoneme
# 29    NaN     NaN   lw1        0.0       0.0  phoneme
# 31    NaN     NaN   lw1        0.0       0.0  phoneme
# 32    NaN     NaN   lw1        0.0       0.0  phoneme
# 33    NaN     NaN   lw1        0.0       0.0  phoneme
# 35    NaN     NaN   lw1        0.0       0.0  phoneme
# 36    NaN     NaN   lw1        0.0       0.0  phoneme
# 37    NaN     NaN   lw1        0.0       0.0  phoneme
# 39    NaN     NaN   lw1        0.0       0.0  phoneme
# 40    NaN     NaN   lw1        0.0       0.0  phoneme
# 42    NaN     NaN   lw1        0.0       0.0  phoneme
# 44    NaN     NaN   lw1        0.0       0.0  phoneme
# 45    NaN     NaN   lw1        0.0       0.0  phoneme
# 46    NaN     NaN   lw1        0.0       0.0  phoneme
# 48    NaN     NaN   lw1        0.0       0.0  phoneme
# 49    NaN     NaN   lw1        0.0       0.0  phoneme
# 50    NaN     NaN   lw1        0.0       0.0  phoneme
# 51    NaN     NaN   lw1        0.0       0.0  phoneme
# 53    NaN     NaN   lw1        0.0       0.0  phoneme
# 55    NaN     NaN   lw1        0.0       0.0  phoneme
# 56    NaN     NaN   lw1        0.0       0.0  phoneme
# 57    NaN     NaN   lw1        0.0       0.0  phoneme
# 59    NaN     NaN   lw1        0.0       0.0  phoneme
# 61    NaN     NaN   lw1        0.0       0.0  phoneme
# 63    NaN     NaN   lw1        0.0       0.0  phoneme
# 64    NaN     NaN   lw1        0.0       0.0  phoneme
# 65    NaN     NaN   lw1        0.0       0.0  phoneme
# 66    NaN     NaN   lw1        0.0       0.0  phoneme
# 67    NaN     NaN   lw1        0.0       0.0  phoneme
# 68    NaN     NaN   lw1        0.0       0.0  phoneme
#
#                        meg_file  start                    sound   onset  ...  \
# 0   A0255_MASC_2_30Mar17_01.con   0.00  stimuli/audio/lw1_0.wav  15.473  ...
# 2   A0255_MASC_2_30Mar17_01.con   0.17  stimuli/audio/lw1_0.wav  15.643  ...
# 3   A0255_MASC_2_30Mar17_01.con   0.24  stimuli/audio/lw1_0.wav  15.713  ...
# 4   A0255_MASC_2_30Mar17_01.con   0.31  stimuli/audio/lw1_0.wav  15.783  ...
# 6   A0255_MASC_2_30Mar17_01.con   0.41  stimuli/audio/lw1_0.wav  15.883  ...
# 7   A0255_MASC_2_30Mar17_01.con   0.49  stimuli/audio/lw1_0.wav  15.963  ...
# 8   A0255_MASC_2_30Mar17_01.con   0.55  stimuli/audio/lw1_0.wav  16.023  ...
# 10  A0255_MASC_2_30Mar17_01.con   0.67  stimuli/audio/lw1_0.wav  16.143  ...
# 11  A0255_MASC_2_30Mar17_01.con   0.79  stimuli/audio/lw1_0.wav  16.263  ...
# 12  A0255_MASC_2_30Mar17_01.con   1.08  stimuli/audio/lw1_0.wav  16.553  ...
# 14  A0255_MASC_2_30Mar17_01.con   1.23  stimuli/audio/lw1_0.wav  16.703  ...
# 15  A0255_MASC_2_30Mar17_01.con   1.34  stimuli/audio/lw1_0.wav  16.813  ...
# 16  A0255_MASC_2_30Mar17_01.con   1.63  stimuli/audio/lw1_0.wav  17.103  ...
# 18  A0255_MASC_2_30Mar17_01.con   1.84  stimuli/audio/lw1_0.wav  17.313  ...
# 19  A0255_MASC_2_30Mar17_01.con   1.89  stimuli/audio/lw1_0.wav  17.363  ...
# 20  A0255_MASC_2_30Mar17_01.con   1.96  stimuli/audio/lw1_0.wav  17.433  ...
# 21  A0255_MASC_2_30Mar17_01.con   2.04  stimuli/audio/lw1_0.wav  17.513  ...
# 23  A0255_MASC_2_30Mar17_01.con   2.17  stimuli/audio/lw1_0.wav  17.643  ...
# 25  A0255_MASC_2_30Mar17_01.con   2.26  stimuli/audio/lw1_0.wav  17.733  ...
# 27  A0255_MASC_2_30Mar17_01.con   2.45  stimuli/audio/lw1_0.wav  17.923  ...
# 28  A0255_MASC_2_30Mar17_01.con   2.51  stimuli/audio/lw1_0.wav  17.983  ...
# 29  A0255_MASC_2_30Mar17_01.con   2.54  stimuli/audio/lw1_0.wav  18.013  ...
# 31  A0255_MASC_2_30Mar17_01.con   2.74  stimuli/audio/lw1_0.wav  18.213  ...
# 32  A0255_MASC_2_30Mar17_01.con   2.79  stimuli/audio/lw1_0.wav  18.263  ...
# 33  A0255_MASC_2_30Mar17_01.con   2.85  stimuli/audio/lw1_0.wav  18.323  ...
# 35  A0255_MASC_2_30Mar17_01.con   2.96  stimuli/audio/lw1_0.wav  18.433  ...
# 36  A0255_MASC_2_30Mar17_01.con   3.03  stimuli/audio/lw1_0.wav  18.503  ...
# 37  A0255_MASC_2_30Mar17_01.con   3.10  stimuli/audio/lw1_0.wav  18.573  ...
# 39  A0255_MASC_2_30Mar17_01.con   3.21  stimuli/audio/lw1_0.wav  18.683  ...
# 40  A0255_MASC_2_30Mar17_01.con   3.28  stimuli/audio/lw1_0.wav  18.753  ...
# 42  A0255_MASC_2_30Mar17_01.con   3.35  stimuli/audio/lw1_0.wav  18.823  ...
# 44  A0255_MASC_2_30Mar17_01.con   3.48  stimuli/audio/lw1_0.wav  18.953  ...
# 45  A0255_MASC_2_30Mar17_01.con   3.56  stimuli/audio/lw1_0.wav  19.033  ...
# 46  A0255_MASC_2_30Mar17_01.con   3.64  stimuli/audio/lw1_0.wav  19.113  ...
# 48  A0255_MASC_2_30Mar17_01.con   3.78  stimuli/audio/lw1_0.wav  19.253  ...
# 49  A0255_MASC_2_30Mar17_01.con   3.85  stimuli/audio/lw1_0.wav  19.323  ...
# 50  A0255_MASC_2_30Mar17_01.con   3.92  stimuli/audio/lw1_0.wav  19.393  ...
# 51  A0255_MASC_2_30Mar17_01.con   3.94  stimuli/audio/lw1_0.wav  19.413  ...
# 53  A0255_MASC_2_30Mar17_01.con   4.09  stimuli/audio/lw1_0.wav  19.563  ...
# 55  A0255_MASC_2_30Mar17_01.con   4.22  stimuli/audio/lw1_0.wav  19.693  ...
# 56  A0255_MASC_2_30Mar17_01.con   4.32  stimuli/audio/lw1_0.wav  19.793  ...
# 57  A0255_MASC_2_30Mar17_01.con   4.37  stimuli/audio/lw1_0.wav  19.843  ...
# 59  A0255_MASC_2_30Mar17_01.con   4.45  stimuli/audio/lw1_0.wav  19.923  ...
# 61  A0255_MASC_2_30Mar17_01.con   4.54  stimuli/audio/lw1_0.wav  20.013  ...
# 63  A0255_MASC_2_30Mar17_01.con   4.68  stimuli/audio/lw1_0.wav  20.153  ...
# 64  A0255_MASC_2_30Mar17_01.con   4.73  stimuli/audio/lw1_0.wav  20.203  ...
# 65  A0255_MASC_2_30Mar17_01.con   4.80  stimuli/audio/lw1_0.wav  20.273  ...
# 66  A0255_MASC_2_30Mar17_01.con   4.83  stimuli/audio/lw1_0.wav  20.303  ...
# 67  A0255_MASC_2_30Mar17_01.con   4.90  stimuli/audio/lw1_0.wav  20.373  ...
# 68  A0255_MASC_2_30Mar17_01.con   4.96  stimuli/audio/lw1_0.wav  20.433  ...
#
#       voice pronounced word  intercept voiced  is_word  wordfreq half  task  \
# 0   Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 2   Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 3   Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 4   Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 6   Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 7   Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 8   Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 10  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 11  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 12  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 14  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 15  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 16  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 18  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 19  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 20  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 21  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 23  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 25  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 27  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 28  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 29  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 31  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 32  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 33  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 35  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 36  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 37  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 39  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 40  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 42  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 44  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 45  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 46  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 48  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 49  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 50  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 51  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 53  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 55  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 56  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 57  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 59  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 61  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 63  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 64  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 65  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 66  Allison        1.0  NaN        1.0   True    False       NaN    0     0
# 67  Allison        1.0  NaN        1.0  False    False       NaN    0     0
# 68  Allison        1.0  NaN        1.0   True    False       NaN    0     0
#
#    session
# 0        0
# 2        0
# 3        0
# 4        0
# 6        0
# 7        0
# 8        0
# 10       0
# 11       0
# 12       0
# 14       0
# 15       0
# 16       0
# 18       0
# 19       0
# 20       0
# 21       0
# 23       0
# 25       0
# 27       0
# 28       0
# 29       0
# 31       0
# 32       0
# 33       0
# 35       0
# 36       0
# 37       0
# 39       0
# 40       0
# 42       0
# 44       0
# 45       0
# 46       0
# 48       0
# 49       0
# 50       0
# 51       0
# 53       0
# 55       0
# 56       0
# 57       0
# 59       0
# 61       0
# 63       0
# 64       0
# 65       0
# 66       0
# 67       0
# 68       0
#
# [50 rows x 27 columns]

# %%
epochs.events
# Out:
# array([[ 15473,      1,      1],
#        [ 15553,      1,      1],
#        [ 15643,      1,      1],
#        ...,
#        [355156,      1,      1],
#        [355236,      1,      1],
#        [355246,      1,      1]])

# %%
XX = words.average()

# %%
fig_evo_word = XX.plot(spatial_colors=True, show=False)

# %%
XX.plot_image()

# %%
XX.plot_psd()
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
#     Using multitaper spectrum estimation with 7 DPSS windows
# /home/subbainria/anaconda3/lib/python3.8/site-packages/mne/viz/utils.py:137: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 720x252 with 2 Axes>
# <MNELineFigure size 720x252 with 2 Axes>

# %%
XX.plot_topomap()
# Out:
# <MNEFigure size 540x158.4 with 5 Axes>
# <MNEFigure size 540x158.4 with 5 Axes>

# %%
select_picks = np.concatenate(
    (mne.pick_types(raw.info, meg=True)[-32:],
     #mne.pick_types(raw.info, meg=False, ref_meg=True)
    ))
plot_kwargs = dict(
    duration=360, order=select_picks, n_channels=len(select_picks),
    scalings={"mag": 8e-13, "ref_meg": 2e-11})
raw.plot(**plot_kwargs)
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
sampling_freq = raw.info['sfreq']
start_stop_seconds = np.array([11, 13])
start_sample, stop_sample = (start_stop_seconds * sampling_freq).astype(int)
channel_index = 0
raw_selection = raw[channel_index, start_sample:stop_sample]
print(raw_selection)
# Out:
# (array([[ 2.58823545e-14,  2.92958700e-14,  3.34390625e-14, ...,
#         -4.39562684e-14, -3.00919823e-14, -1.67403319e-14]]), array([11.   , 11.001, 11.002, ..., 12.997, 12.998, 12.999]))

# %%
sampling_freq
# Out:
# 1000.0

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
import matplotlib.pyplot as plt
sampling_freq = raw.info['sfreq']
start_stop_seconds = np.array([394, 400])
start_sample, stop_sample = (start_stop_seconds * sampling_freq).astype(int)
channel_names = ['MEG 001', 'MEG 208']
two_meg_chans = raw[channel_names, start_sample:stop_sample]
y_offset = np.array([1e-11, 0])  # just enough to separate the channel traces
x = two_meg_chans[1]
y = two_meg_chans[0].T + y_offset
lines = plt.plot(x, y)
plt.legend(lines, channel_names)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from os.path import join

import mne
from mne.decoding import ReceptiveField
from sklearn.model_selection import KFold
from sklearn.preprocessing import scale

# %%
path = mne.datasets.mtrf.data_path()
decim = 2
data = loadmat(join(path, 'speech_data.mat'))
raw = data['EEG'].T
speech = data['envelope'].T
sfreq = float(data['Fs'])
sfreq /= decim
speech = mne.filter.resample(speech, down=decim, npad='auto')
raw = mne.filter.resample(raw, down=decim, npad='auto')

# Read in channel positions and create our MNE objects from the raw data
montage = mne.channels.make_standard_montage('biosemi128')
info = mne.create_info(montage.ch_names, sfreq, 'eeg').set_montage(montage)
raw = mne.io.RawArray(raw, info)
n_channels = len(raw.ch_names)

# Plot a sample of brain and stimulus activity
fig, ax = plt.subplots()
lns = ax.plot(scale(raw[:, :800][0].T), color='k', alpha=.1)
ln1 = ax.plot(scale(speech[0, :800]), color='r', lw=2)
ax.legend([lns[0], ln1[0]], ['EEG', 'Speech Envelope'], frameon=False)
ax.set(title="Sample activity", xlabel="Time (s)")
mne.viz.tight_layout()
# Out:
# Using default location ~/mne_data for mtrf...
# Creating ~/mne_data
# Downloading file 'mTRF_1.5.zip' from 'https://osf.io/h85s2/download?version=1' to '/home/subbainria/mne_data'.
# 100%|█████████████████████████████████████| 58.1M/58.1M [00:00<00:00, 21.2GB/s]
# Unzipping contents of '/home/subbainria/mne_data/mTRF_1.5.zip' to '/home/subbainria/mne_data'
# Attempting to create new mne-python configuration file:
# /home/subbainria/.mne/mne-python.json
# Creating RawArray with float64 data, n_channels=128, n_times=7677
#     Range : 0 ... 7676 =      0.000 ...   119.938 secs
# Ready.

# %%
data['envelope'].T.shape
# Out:
# (1, 15354)

# %%
data['EEG'].T.shape
# Out:
# (128, 15354)

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Fs', 'spectrogram', 'envelope', 'EEG'])

# %%
data['spectrogram'].shape
# Out:
# (15354, 16)

# %%
speech.shape
# Out:
# (1, 7677)

# %%
info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: A1, A2, A3, A4, A5, A6, A7, A8, A9, A10, A11, A12, A13, A14, ...
#  chs: 128 EEG
#  custom_ref_applied: False
#  dig: 131 items (3 Cardinal, 128 EEG)
#  highpass: 0.0 Hz
#  lowpass: 32.0 Hz
#  meas_date: unspecified
#  nchan: 128
#  projs: []
#  sfreq: 64.0 Hz
# >
